# %%
import random

# %%
a1=[]
a2=[]
a3=[]
a4=[]
a5=[]

# %%
for _ in range(1000):
      a1.append(random.randint(0,100))
      a2.append(random.randint(50,70))
      a3.append(random.randint(10,20))
      a4.append(random.randint(8,10))
      a5.append(random.randint(20,80))

# %%
a1
# Out:
# [88,
#  26,
#  91,
#  16,
#  55,
#  5,
#  48,
#  99,
#  37,
#  18,
#  43,
#  93,
#  34,
#  37,
#  8,
#  11,
#  83,
#  98,
#  3,
#  60,
#  39,
#  3,
#  38,
#  49,
#  16,
#  76,
#  35,
#  17,
#  50,
#  0,
#  71,
#  24,
#  79,
#  15,
#  51,
#  42,
#  36,
#  86,
#  17,
#  46,
#  94,
#  96,
#  29,
#  93,
#  54,
#  25,
#  15,
#  74,
#  83,
#  81,
#  61,
#  36,
#  23,
#  30,
#  48,
#  13,
#  36,
#  95,
#  20,
#  5,
#  62,
#  63,
#  70,
#  88,
#  1,
#  77,
#  46,
#  98,
#  82,
#  72,
#  6,
#  67,
#  17,
#  38,
#  39,
#  38,
#  69,
#  21,
#  21,
#  36,
#  30,
#  21,
#  32,
#  1,
#  80,
#  39,
#  26,
#  21,
#  46,
#  61,
#  52,
#  38,
#  22,
#  19,
#  25,
#  57,
#  28,
#  56,
#  56,
#  59,
#  39,
#  52,
#  86,
#  12,
#  8,
#  35,
#  36,
#  40,
#  72,
#  56,
#  93,
#  72,
#  77,
#  82,
#  70,
#  39,
#  13,
#  7,
#  44,
#  86,
#  50,
#  85,
#  57,
#  10,
#  39,
#  82,
#  64,
#  9,
#  23,
#  50,
#  60,
#  77,
#  2,
#  62,
#  50,
#  86,
#  4,
#  96,
#  36,
#  36,
#  66,
#  62,
#  27,
#  53,
# ...

# %%
df={
    'grade':a1,
    'weight':a2,
    'friends':a3,
    'cousins':a4,
    'projects':a5
}

# %%
df
# Out:
# {'grade': [88,
#   26,
#   91,
#   16,
#   55,
#   5,
#   48,
#   99,
#   37,
#   18,
#   43,
#   93,
#   34,
#   37,
#   8,
#   11,
#   83,
#   98,
#   3,
#   60,
#   39,
#   3,
#   38,
#   49,
#   16,
#   76,
#   35,
#   17,
#   50,
#   0,
#   71,
#   24,
#   79,
#   15,
#   51,
#   42,
#   36,
#   86,
#   17,
#   46,
#   94,
#   96,
#   29,
#   93,
#   54,
#   25,
#   15,
#   74,
#   83,
#   81,
#   61,
#   36,
#   23,
#   30,
#   48,
#   13,
#   36,
#   95,
#   20,
#   5,
#   62,
#   63,
#   70,
#   88,
#   1,
#   77,
#   46,
#   98,
#   82,
#   72,
#   6,
#   67,
#   17,
#   38,
#   39,
#   38,
#   69,
#   21,
#   21,
#   36,
#   30,
#   21,
#   32,
#   1,
#   80,
#   39,
#   26,
#   21,
#   46,
#   61,
#   52,
#   38,
#   22,
#   19,
#   25,
#   57,
#   28,
#   56,
#   56,
#   59,
#   39,
#   52,
#   86,
#   12,
#   8,
#   35,
#   36,
#   40,
#   72,
#   56,
#   93,
#   72,
#   77,
#   82,
#   70,
#   39,
#   13,
#   7,
#   44,
#   86,
#   50,
#   85,
#   57,
#   10,
#   39,
# ...

# %%
import pandas as pd

# %%
df1=pd.DataFrame(df)

# %%
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       88      51       11        8        22
# 1       26      60       14       10        27
# 2       91      62       15        9        32
# 3       16      52       12        9        27
# 4       55      61       11        9        65
# ..     ...     ...      ...      ...       ...
# 995     61      69       12        8        20
# 996     70      67       17        8        76
# 997      6      61       12        9        67
# 998    100      58       19        9        25
# 999     60      63       16       10        39
#
# [1000 rows x 5 columns]

# %%
df1.describe()
# Out:
#             grade       weight      friends     cousins     projects
# count  1000.00000  1000.000000  1000.000000  1000.00000  1000.000000
# mean     48.78400    59.577000    14.905000     9.03500    49.118000
# std      28.79407     5.908382     3.164805     0.80773    17.480493
# min       0.00000    50.000000    10.000000     8.00000    20.000000
# 25%      24.00000    54.750000    12.000000     8.00000    34.000000
# 50%      48.00000    60.000000    15.000000     9.00000    48.000000
# 75%      74.00000    64.000000    18.000000    10.00000    65.000000
# max     100.00000    70.000000    20.000000    10.00000    80.000000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
df1['grade'].count
# Out:
# <bound method Series.count of 0       88
# 1       26
# 2       91
# 3       16
# 4       55
#       ...
# 995     61
# 996     70
# 997      6
# 998    100
# 999     60
# Name: grade, Length: 1000, dtype: int64>

# %%
friend18=df1['friends']>18

# %%
df1[friend18]
# Out:
#      grade  weight  friends  cousins  projects
# 14       8      51       20       10        56
# 15      11      55       19        8        58
# 19      60      50       19       10        69
# 24      16      56       19       10        20
# 33      15      54       19        9        75
# ..     ...     ...      ...      ...       ...
# 979     94      66       19        8        72
# 982     43      67       20       10        73
# 988     52      64       19        9        27
# 991     85      56       20        8        31
# 998    100      58       19        9        25
#
# [174 rows x 5 columns]

# %%
grade50=df1['grade']>50

# %%
df1[grade50]
# Out:
#      grade  weight  friends  cousins  projects
# 0       88      51       11        8        22
# 2       91      62       15        9        32
# 4       55      61       11        9        65
# 7       99      54       13        9        45
# 11      93      63       18       10        79
# ..     ...     ...      ...      ...       ...
# 993     77      53       16       10        74
# 995     61      69       12        8        20
# 996     70      67       17        8        76
# 998    100      58       19        9        25
# 999     60      63       16       10        39
#
# [472 rows x 5 columns]

# %%
df1[friend18 & grade50]
# Out:
#      grade  weight  friends  cousins  projects
# 19      60      50       19       10        69
# 34      51      69       19        9        65
# 40      94      57       19        9        73
# 111     72      58       19        9        21
# 131     77      62       19        8        43
# ..     ...     ...      ...      ...       ...
# 959     72      53       20       10        25
# 979     94      66       19        8        72
# 988     52      64       19        9        27
# 991     85      56       20        8        31
# 998    100      58       19        9        25
#
# [83 rows x 5 columns]

# %%
df1[friend18 & grade50]['weight']
# Out:
# 19     50
# 34     69
# 40     57
# 111    58
# 131    62
#        ..
# 959    53
# 979    66
# 988    64
# 991    56
# 998    58
# Name: weight, Length: 83, dtype: int64

# %%
from matplotlib import pyplot as plt

# %%
df1[friend18 & grade50]. plot()
# Out:
# <Axes: >

# %%
matplotlib inline

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1[friend18 & grade50]. plot()
# Out:
# <Axes: >

# %%
df1[friend18 & grade50]. plot(x='grade',y='projects')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend18 &  grade50]. plot(x = 'grade',y = 'projects',kind = 'box')
# Out:
# <Axes: >

# %%
df1[friend18 & grade50]. plot(x = 'grade',y = 'projects',kind = 'bar')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend18 & grade50]. plot(x = 'grade',y = 'projects',kind = 'scatter')
# Out:
# <Axes: xlabel='grade', ylabel='projects'>

# %%
df1[friend18 & grade50]. plot(x = 'grade',y ='projects',kind = 'area')
# Out:
# <Axes: xlabel='grade'>

# %%
pip install matplotlib

# %%
from matplotlib import pyplot as plt

# %%
fdf=df1[friend18 & grade50]

# %%
fdf
# Out:
#      grade  weight  friends  cousins  projects
# 19      60      50       19       10        69
# 34      51      69       19        9        65
# 40      94      57       19        9        73
# 111     72      58       19        9        21
# 131     77      62       19        8        43
# ..     ...     ...      ...      ...       ...
# 959     72      53       20       10        25
# 979     94      66       19        8        72
# 988     52      64       19        9        27
# 991     85      56       20        8        31
# 998    100      58       19        9        25
#
# [83 rows x 5 columns]
